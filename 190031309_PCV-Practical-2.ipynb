# %% [markdown]
# # Color Image Processing Using OpenCV and Python

# %% [markdown]
# # IN-LAB TASK:-

# %%
import matplotlib.pyplot as plt
import cv2

BGR = cv2.imread("dragon.jpg")
plt.figure(figsize =(10, 10))


# show BGR lena
plt.subplot(3, 3, 1)
plt.imshow(BGR)
plt.axis('off')
plt.title('BGR')
plt.figure(figsize =(10, 10))

# BGR to RGB
RGB = cv2.cvtColor(BGR, cv2.COLOR_BGR2RGB)
plt.subplot(3, 3, 2)
plt.imshow(RGB)
plt.axis('off')
plt.title('RGB')
plt.figure(figsize =(10, 10))


# BGR to GRAY
GRAY = cv2.cvtColor(BGR, cv2.COLOR_BGR2GRAY)
plt.subplot(3, 3, 3)
plt.imshow(GRAY)
plt.axis('off')
plt.title('GRAY')
plt.figure(figsize =(10, 10))


# BGR to CIE XYZ
CIEXYZ = cv2.cvtColor(BGR, cv2.COLOR_BGR2XYZ)
plt.subplot(3, 3, 4)
plt.imshow(CIEXYZ)
plt.axis('off')
plt.title('CIEXYZ')
plt.figure(figsize =(10, 10))


# BGR to YCrCb
YCrCb = cv2.cvtColor(BGR, cv2.COLOR_BGR2YCrCb)
plt.subplot(3, 3, 5)
plt.imshow(YCrCb)
plt.axis('off')
plt.title('YCrCb')
plt.figure(figsize =(10, 10))


# BGR to HSV
HSV = cv2.cvtColor(BGR, cv2.COLOR_BGR2HSV)
plt.subplot(3, 3, 6)
plt.imshow(HSV)
plt.axis('off')
plt.title('HSV')
plt.figure(figsize =(10, 10))


# BGR to HLS
HLS = cv2.cvtColor(BGR, cv2.COLOR_BGR2HLS)
plt.subplot(3, 3, 7)
plt.imshow(HLS)
plt.axis('off')
plt.title('HLS')
plt.figure(figsize =(10, 10))


# BGR to CIE L*a*b
Lab = cv2.cvtColor(BGR, cv2.COLOR_BGR2Lab)
plt.subplot(3, 3, 8)
plt.imshow(Lab)
plt.axis('off')
plt.title('Lab')
plt.figure(figsize =(10, 10))


# BGR to CIE L*u*v
Luv = cv2.cvtColor(BGR, cv2.COLOR_BGR2Luv)
plt.subplot(3, 3, 9)
plt.imshow(Luv)
plt.axis('off')
plt.title('Luv')
plt.figure(figsize =(10, 10))

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("dragon.jpg")

# converting to gray scale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# remove noise
img = cv2.GaussianBlur(gray,(3,3),0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
plt.figure(figsize =(10, 10))
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("dragon.jpg", 0)
heatmap = cv2.applyColorMap(image, cv2.COLORMAP_HOT)

plt.figure(figsize =(10, 10))
plt.subplot(2, 2, 1)
plt.imshow(image)
plt.axis('off')
plt.title('Original')
plt.subplot(2, 2, 2)
plt.imshow(heatmap)
plt.axis('off')
plt.title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
import matplotlib.pyplot as plt
import cv2
  
img = cv2.imread("dragon.jpg")
plt.imshow(img, cmap ='nipy_spectral')

# %% [markdown]
# # POST-LAB TASK:-

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# read image
img = cv2.imread('dragon.jpg')

mask1 = cv2.imread('dragon.jpg',0)
result1 = img.copy()
result1[mask1 == 0] = 0
result1[mask1 != 0] = img[mask1 != 0]

mask2 = cv2.imread('dragon.jpg') / 255.0

plt.imshow(mask1)
# save results
cv2.imwrite('dragon.jpg', result1)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# read image
img = cv2.imread('dragon.jpg')

mask1 = cv2.imread('dragon.jpg',0)
result1 = img.copy()
result1[mask1 == 0] = 0
result1[mask1 != 0] = img[mask1 != 0]

mask2 = cv2.imread('dragon.jpg') / 255.0

plt.imshow(result1)
# save results
cv2.imwrite('dragon.jpg', result1)
# Out:
# True

# %%
import skimage
from skimage import data, io, filters
image = skimage.io.imread('dragon.jpg')

# display the image
fig, ax = plt.subplots()
plt.imshow(image)
plt.show()

colors = ("red", "green", "blue")
channel_ids = (0, 1, 2)

# create the histogram plot, with three lines, one for
# each color
plt.figure()
plt.xlim([0, 256])
for channel_id, c in zip(channel_ids, colors):
    histogram, bin_edges = np.histogram(
        image[:, :, channel_id], bins=256, range=(0, 256)
    )
    plt.plot(bin_edges[0:-1], histogram, color=c)

plt.title("Color Histogram")
plt.xlabel("Color value")
plt.ylabel("Pixel count")

plt.show()
